# %%
import pandas as pd

try:
    movies_df = pd.read_csv('movies_metadata.csv', low_memory=False)
    ratings_df = pd.read_csv('ratings.csv')
    display(movies_df.head())
    display(ratings_df.head())
except FileNotFoundError:
    print("Error: One or both of the CSV files were not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Data Shape and Info
print("Movies DataFrame Shape:", movies_df.shape)
print("\nMovies DataFrame Info:")
display(movies_df.info())
print("\nRatings DataFrame Shape:", ratings_df.shape)
print("\nRatings DataFrame Info:")
display(ratings_df.info())

# Descriptive Statistics
print("\nMovies DataFrame Descriptive Statistics:")
display(movies_df.describe(include='all'))
print("\nRatings DataFrame Descriptive Statistics:")
display(ratings_df.describe())

# Missing Values
print("\nMovies DataFrame Missing Values:")
display(movies_df.isnull().sum() / len(movies_df) * 100)
print("\nRatings DataFrame Missing Values:")
display(ratings_df.isnull().sum() / len(ratings_df) * 100)

# Unique Values
print("\nMovies DataFrame Unique Values:")
print("title:", movies_df['title'].nunique())
print("genres:", movies_df['genres'].nunique())
print("release_date:", movies_df['release_date'].nunique())
print("movieId:", movies_df['movieId'].nunique())
print("\nRatings DataFrame Unique Values:")
print("userId:", ratings_df['userId'].nunique())
print("movieId:", ratings_df['movieId'].nunique())

print("\nMovies 'id' column data type:", movies_df['movieId'].dtype)
print("Ratings 'movieId' column data type:", ratings_df['movieId'].dtype)

# Data Distribution (Histograms - limited due to potential memory issues with large datasets)
import matplotlib.pyplot as plt

print("\nRatings Distribution:")
plt.figure(figsize=(8, 6))
plt.hist(ratings_df['rating'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Ratings')
plt.show()

# Correlation Analysis (movies_df)
print("\nCorrelation Matrix (movies_df):")
numerical_features = movies_df.select_dtypes(include=['number']).columns
display(movies_df[numerical_features].corr())

# Identify Common Columns and Data Type Compatibility
print("\nPotential Common Columns for Merging:")
print("movies_df: id")
print("ratings_df: movieId")
print("Data Type Compatibility Check:")
print("movies_df['id'] type:", movies_df['movieId'].dtype)
print("ratings_df['movieId'] type:", ratings_df['movieId'].dtype)
# Out:
# Movies DataFrame Shape: (45463, 24)
#
# Movies DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  object
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   movieId                45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  object
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
# ...

# %%
import pandas as pd
import numpy as np

# Remove unused columns
columns_to_remove = ['adult', 'belongs_to_collection', 'homepage', 'imdb_id', 'original_title', 'overview', 'poster_path', 'production_companies', 'production_countries', 'spoken_languages', 'tagline', 'video', 'status']
merged_df = merged_df.drop(columns=columns_to_remove, errors='ignore')

# Handle missing values
for col in merged_df.columns:
    if merged_df[col].dtype in ['int64', 'float64']:
        merged_df[col] = merged_df[col].fillna(merged_df[col].median())
    elif merged_df[col].dtype == 'object':
        merged_df[col] = merged_df[col].fillna('Unknown')

# Handle outliers (using IQR method for numerical columns)
for col in merged_df.select_dtypes(include=['number']):
    Q1 = merged_df[col].quantile(0.25)
    Q3 = merged_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    merged_df[col] = np.clip(merged_df[col], lower_bound, upper_bound)

# Remove duplicates
merged_df.drop_duplicates(inplace=True)
display(merged_df.head())
# Out:
#      budget  movieId original_language popularity release_date      revenue  \
# 0  30000000    862.0                en  21.946943   1995-10-30  173713725.0
# 1  30000000    862.0                en  21.946943   1995-10-30  173713725.0
# 2  30000000    862.0                en  21.946943   1995-10-30  173713725.0
# 3  30000000    862.0                en  21.946943   1995-10-30  173713725.0
# 4  30000000    862.0                en  21.946943   1995-10-30  173713725.0
#
#    runtime      title  vote_average  vote_count  userId  rating  timestamp  \
# 0     81.0  Toy Story           7.7      1586.5    1923     3.0  858335006
# 1     81.0  Toy Story           7.7      1586.5    2103     5.0  946044912
# 2     81.0  Toy Story           7.7      1586.5    5380     1.5  878941641
# 3     81.0  Toy Story           7.7      1586.5    6177     4.0  859415226
# 4     81.0  Toy Story           7.7      1586.5    6525     4.0  857388995
#
#             genres_flattened
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Distribution of movie ratings
plt.figure(figsize=(8, 6))
plt.hist(merged_df['rating'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Ratings')
plt.show()

# 2. Correlation matrix heatmap
numerical_cols = ['rating', 'runtime', 'budget', 'revenue', 'popularity', 'vote_average', 'vote_count']
correlation_matrix = merged_df[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
from google.colab import files
merged_df.to_csv('final_dataset.csv', encoding = 'utf-8-sig')
files.download('final_dataset.csv')
